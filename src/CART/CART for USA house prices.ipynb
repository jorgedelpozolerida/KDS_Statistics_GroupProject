# %%
import os

import pandas as pd
import numpy as np

from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

# %%
ranks = {}
def ranking(ranks, names, order=1):
    minmax = MinMaxScaler()
    ranks = minmax.fit_transform(order*np.array([ranks]).T).T[0]
    ranks = map(lambda x: round(x,2), ranks)
    return dict(zip(names, ranks))

# %%
df = pd.read_csv("../../datasets/USA_houseprices_2014/preprocessed_data_USAhouseprices2014.csv")
df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0  0.333333    0.18750     0.073652  0.006775     0.2         0.0   0.0
# 1  0.555556    0.31250     0.249051  0.007835     0.4         0.0   1.0
# 2  0.333333    0.25000     0.118451  0.010534     0.0         0.0   0.0
# 3  0.333333    0.28125     0.123766  0.006885     0.0         0.0   0.0
# 4  0.444444    0.31250     0.119210  0.009186     0.0         0.0   0.0
#
#    condition  sqft_basement  year_since_1st_renovation      city  statezip  \
# 0       0.50       0.000000                   0.921053  0.837209  0.815789
# 1       1.00       0.058091                   0.184211  0.813953  0.763158
# 2       0.75       0.000000                   0.578947  0.418605  0.342105
# 3       0.75       0.207469                   0.552632  0.069767  0.092105
# 4       0.75       0.165975                   0.807018  0.720930  0.407895
#
#    have_basement      price
# 0          False   313000.0
# 1           True  2384000.0
# 2          False   342000.0
# 3           True   420000.0
# 4           True   550000.0

# %%
# df = df.drop(['Unnamed: 0'], axis=1)
# df = df.drop(['have_basement'], axis=1)
# df

# %%
X = df.copy()
y = X.pop("price")
colnames = X.columns

# %%
model = DecisionTreeRegressor()
model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
    
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.01253
# Feature: 1, Score: 0.03330
# Feature: 2, Score: 0.55048
# Feature: 3, Score: 0.07013
# Feature: 4, Score: 0.02511
# Feature: 5, Score: 0.01191
# Feature: 6, Score: 0.03453
# Feature: 7, Score: 0.00865
# Feature: 8, Score: 0.01809
# Feature: 9, Score: 0.03089
# Feature: 10, Score: 0.07481
# Feature: 11, Score: 0.12827
# Feature: 12, Score: 0.00129

# %%
cart = DecisionTreeRegressor()
cart.fit(X,y)
ranks["CART"] = ranking(cart.feature_importances_, colnames);
ranks
# Out:
# {'CART': {'bedrooms': 0.02,
#   'bathrooms': 0.04,
#   'sqft_living': 1.0,
#   'sqft_lot': 0.13,
#   'floors': 0.04,
#   'waterfront': 0.02,
#   'view': 0.06,
#   'condition': 0.01,
#   'sqft_basement': 0.03,
#   'year_since_1st_renovation': 0.06,
#   'city': 0.15,
#   'statezip': 0.24,
#   'have_basement': 0.0}}

# %%
decimalrank_df = pd.DataFrame()

# Join preranks in dataframe
for method_name, rank_list in ranks.items():
    df_Temp = pd.DataFrame(data = {method_name:pd.Series(rank_list)})
    decimalrank_df = pd.concat([decimalrank_df,df_Temp ], axis=1)

rank_df = pd.DataFrame()
# Create new integer ranks
for method_name, rank_list in ranks.items():
    rank_df[method_name] = decimalrank_df[method_name].rank(ascending=False)

rank_df['feature_name'] = rank_df.index

# %%
ranksout = rank_df.melt(id_vars = 'feature_name', var_name='method', value_name='feature_rank')
ranksout['dataset'] = 'USA_houseprices_2014'
ranksout
# Out:
#                  feature_name method  feature_rank               dataset
# 0                    bedrooms   CART          10.5  USA_houseprices_2014
# 1                   bathrooms   CART           7.5  USA_houseprices_2014
# 2                 sqft_living   CART           1.0  USA_houseprices_2014
# 3                    sqft_lot   CART           4.0  USA_houseprices_2014
# 4                      floors   CART           7.5  USA_houseprices_2014
# 5                  waterfront   CART          10.5  USA_houseprices_2014
# 6                        view   CART           5.5  USA_houseprices_2014
# 7                   condition   CART          12.0  USA_houseprices_2014
# 8               sqft_basement   CART           9.0  USA_houseprices_2014
# 9   year_since_1st_renovation   CART           5.5  USA_houseprices_2014
# 10                       city   CART           3.0  USA_houseprices_2014
# 11                   statezip   CART           2.0  USA_houseprices_2014
# 12              have_basement   CART          13.0  USA_houseprices_2014

# %%
ranksout.to_csv('../../data/CART/USA_houseprices_2014.csv', sep=';',index=False)
