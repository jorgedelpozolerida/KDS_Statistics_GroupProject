# %% [markdown]
# https://www.kaggle.com/datasets/prassanth/new-cars-price-2019
#
# MSRP: Selling price in dollars

# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
import pandas as pd
df=pd.read_csv("../datasets/cars/New_cars_cleaned.csv")
df.head()
# Out:
#       MSRP  EPA Fuel Economy Est - City (MPG) Engine Drivetrain  \
# 0  40600.0                               22.0     l4        FWD
# 1  45500.0                               22.0     l4        FWD
# 2  43600.0                               22.0     l4        FWD
# 3  37400.0                               22.0     l4        FWD
# 4  42600.0                               21.0     l4        AWD
#
#    Passenger Capacity  Passenger Doors  Base Curb Weight (lbs)  \
# 0                   5                4                  3790.0
# 1                   5                4                  3829.0
# 2                   5                4                  3821.0
# 3                   5                4                  3783.0
# 4                   5                4                  4026.0
#
#    Passenger Volume (ft³)  Wheelbase (in)  Track Width, Front (in)  ...  \
# 0                   104.0           108.3                     64.2  ...
# ...

# %%
df.describe()
# Out:
#                 MSRP  EPA Fuel Economy Est - City (MPG)  Passenger Capacity  \
# count   32262.000000                       27027.000000        32316.000000
# mean    37707.459426                          19.568202            4.762904
# std     32392.375762                           5.589965            1.824018
# min      6929.000000                           9.000000            0.000000
# 25%     23140.000000                          16.000000            4.000000
# 50%     30557.500000                          18.000000            5.000000
# 75%     40758.750000                          22.000000            5.000000
# max    548800.000000                          66.000000           15.000000
#
#        Passenger Doors  Base Curb Weight (lbs)  Passenger Volume (ft³)  \
# count     32316.000000            19456.000000            16756.000000
# mean          3.263399             3610.225309              100.461522
# ...

# %%
df.shape
# Out:
# (32316, 56)

# %%
#The colums name can be found in the description, they are really detailed, so I am gonna add to appendix
dataset_columns = list(df.columns)
#dataset_columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32316 entries, 0 to 32315
# Data columns (total 56 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   MSRP                                  32262 non-null  float64
#  1   EPA Fuel Economy Est - City (MPG)     27027 non-null  float64
#  2   Engine                                30341 non-null  object
#  3   Drivetrain                            30600 non-null  object
#  4   Passenger Capacity                    32316 non-null  int64
#  5   Passenger Doors                       32316 non-null  int64
#  6   Base Curb Weight (lbs)                19456 non-null  float64
#  7   Passenger Volume (ft³)                16756 non-null  float64
#  8   Wheelbase (in)                        30301 non-null  float64
#  9   Track Width, Front (in)               20130 non-null  float64
# ...

# %%
df.shape
# Out:
# (32316, 56)

# %%
df.isnull().sum()
# Out:
# MSRP                                       54
# EPA Fuel Economy Est - City (MPG)        5289
# Engine                                   1975
# Drivetrain                               1716
# Passenger Capacity                          0
# Passenger Doors                             0
# Base Curb Weight (lbs)                  12860
# Passenger Volume (ft³)                  15560
# Wheelbase (in)                           2015
# Track Width, Front (in)                 12186
# Height, Overall (in)                    16688
# Fuel Tank Capacity, Approx (gal)        16701
# SAE Net Torque @ RPM                     2067
# Fuel System                              2830
# SAE Net Horsepower @ RPM                 2014
# Displacement                             2147
# Trans Description Cont.                  2037
# Trans Type                               1981
# Suspension Type - Front                     0
# Suspension Type - Rear                      0
# ...

# %% [markdown]
# # Delete missing values

# %%
# df=df.dropna(axis=0)

# %%
max_number_of_nas = 10000
df = df.loc[:, (df.isnull().sum(axis=0) <= max_number_of_nas)]

# %%
df.isnull().sum()
# Out:
# MSRP                                      54
# EPA Fuel Economy Est - City (MPG)       5289
# Engine                                  1975
# Drivetrain                              1716
# Passenger Capacity                         0
# Passenger Doors                            0
# Wheelbase (in)                          2015
# SAE Net Torque @ RPM                    2067
# Fuel System                             2830
# SAE Net Horsepower @ RPM                2014
# Displacement                            2147
# Trans Description Cont.                 2037
# Trans Type                              1981
# Suspension Type - Front                    0
# Suspension Type - Rear                     0
# Air Bag-Frontal-Driver                     0
# Air Bag-Frontal-Passenger                  0
# Air Bag-Passenger Switch (On/Off)          0
# Air Bag-Side Body-Front                    0
# Air Bag-Side Body-Rear                     0
# Air Bag-Side Head-Front                    0
# ...

# %%
df.shape
# Out:
# (32316, 49)

# %% [markdown]
# # Numerical values

# %%
df.hist(edgecolor="black", linewidth=1.2, figsize=(30, 30));

# %%
df.corr()
# Out:
# C:\Users\Jani\AppData\Local\Temp\ipykernel_17744\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                           MSRP  \
# MSRP                                  1.000000
# EPA Fuel Economy Est - City (MPG)    -0.310141
# Passenger Capacity                    0.019733
# Passenger Doors                       0.037116
# Wheelbase (in)                        0.052636
# SAE Net Torque @ RPM                  0.603286
# SAE Net Horsepower @ RPM              0.667031
# Displacement                          0.338778
# Air Bag-Frontal-Driver                0.101682
# Air Bag-Frontal-Passenger             0.121955
# Air Bag-Passenger Switch (On/Off)    -0.030036
# Air Bag-Side Body-Front               0.220986
# Air Bag-Side Body-Rear                0.169142
# ...

# %%
sns.set(font_scale=2.25)
plt.figure(figsize=(50,50))
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\Jani\AppData\Local\Temp\ipykernel_17744\2683053377.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,10))
df.corr()["MSRP"].sort_values().plot(kind="barh")
# Out:
# C:\Users\Jani\AppData\Local\Temp\ipykernel_17744\993124348.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["MSRP"].sort_values().plot(kind="barh")
# <AxesSubplot: >

# %%
df
# Out:
#           MSRP  EPA Fuel Economy Est - City (MPG) Engine Drivetrain  \
# 0      40600.0                               22.0     l4        FWD
# 1      45500.0                               22.0     l4        FWD
# 2      43600.0                               22.0     l4        FWD
# 3      37400.0                               22.0     l4        FWD
# 4      42600.0                               21.0     l4        AWD
# ...        ...                                ...    ...        ...
# 32311  45700.0                               22.0     l4        AWD
# 32312  41200.0                               20.0     l5        AWD
# 32313  44850.0                               20.0     l5        AWD
# 32314  41000.0                               20.0     l5        AWD
# 32315  44650.0                               20.0     l5        AWD
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                       5                4           108.3
# ...

# %%
df.shape
# Out:
# (32316, 49)

# %% [markdown]
# # Outlier detection
# there was no outlier

# %%
Q1 = np.percentile(df['MSRP'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['MSRP'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['MSRP'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['MSRP'] <= (Q1-1.5*IQR))
 
''' Removing the Outliers '''
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (32316, 49)
# New Shape:  (32316, 49)

# %% [markdown]
# # Discover unnecessary features

# %%
df['Suspension Type - Front'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Suspension Type - Rear'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Frontal-Driver'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Frontal-Passenger'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Passenger Switch (On/Off)'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Side Body-Front'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Side Body-Rear'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Side Head-Front'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Air Bag-Side Head-Rear'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Brakes-ABS'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Child Safety Rear Door Locks'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Daytime Running Lights'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Fog Lamps'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Fog Lamps'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Parking Aid'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Tire Pressure Monitor'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Back-Up Camera'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Stability Control'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Front Wheel Material'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Front tire speed ratings/cons.type'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Category'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Manufacturer'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Engine'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Drivetrain'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Fuel System'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df['Trans Description Cont.'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df = df.drop(columns=['Suspension Type - Front', 'Suspension Type - Rear', 'Air Bag-Frontal-Driver', 'Air Bag-Frontal-Passenger','Air Bag-Passenger Switch (On/Off)',
                     'Air Bag-Side Body-Front', 'Air Bag-Side Body-Rear', 'Brakes-ABS', 'Fog Lamps', 'Parking Aid','Tire Pressure Monitor', 'Back-Up Camera', 'Stability Control','Front tire speed ratings/cons.type'])

# %%
df.shape
# Out:
# (32316, 35)

# %% [markdown]
# # Encoding

# %% [markdown]
# ### One-hot encoding

# %%
#df.shape

# %%
# hot_categ = ['Front Wheel Material', 'Category', 'Drivetrain', 'Fuel System', 'Trans Description Cont.']
# ohe = pd.get_dummies(data=df, columns=hot_categ)

# %%
# df = ohe
# df

# %% [markdown]
# ### Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
label_categ = ['Front Wheel Material', 'Category', 'Drivetrain', 'Fuel System', 'Trans Description Cont.','Manufacturer','Engine', 'Trans Type', 'Front tire width']

# Encode Categorical Columns
le = LabelEncoder()
df[label_categ] = df[label_categ].apply(le.fit_transform)

# %%
df
# Out:
#           MSRP  EPA Fuel Economy Est - City (MPG)  Engine  Drivetrain  \
# 0      40600.0                               22.0      10           2
# 1      45500.0                               22.0      10           2
# 2      43600.0                               22.0      10           2
# 3      37400.0                               22.0      10           2
# 4      42600.0                               21.0      10           1
# ...        ...                                ...     ...         ...
# 32311  45700.0                               22.0      10           1
# 32312  41200.0                               20.0      11           1
# 32313  44850.0                               20.0      11           1
# 32314  41000.0                               20.0      11           1
# 32315  44650.0                               20.0      11           1
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                       5                4           108.3
# ...

# %%
df['MSRP'].isna().sum()
# Out:
# 54

# %%
df = df[df['MSRP'] > 0]

# %%
df['MSRP'].isna().sum()
# Out:
# 0

# %%
df.replace(np.nan,0)
# Out:
#           MSRP  EPA Fuel Economy Est - City (MPG)  Engine  Drivetrain  \
# 0      40600.0                               22.0      10           2
# 1      45500.0                               22.0      10           2
# 2      43600.0                               22.0      10           2
# 3      37400.0                               22.0      10           2
# 4      42600.0                               21.0      10           1
# ...        ...                                ...     ...         ...
# 32311  45700.0                               22.0      10           1
# 32312  41200.0                               20.0      11           1
# 32313  44850.0                               20.0      11           1
# 32314  41000.0                               20.0      11           1
# 32315  44650.0                               20.0      11           1
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                       5                4           108.3
# ...

# %%
df = df.fillna(0)

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Normalize data

# %%
df.columns
# Out:
# Index(['MSRP', 'EPA Fuel Economy Est - City (MPG)', 'Engine', 'Drivetrain',
#        'Passenger Capacity', 'Passenger Doors', 'Wheelbase (in)',
#        'SAE Net Torque @ RPM', 'Fuel System', 'SAE Net Horsepower @ RPM',
#        'Displacement', 'Trans Description Cont.', 'Trans Type',
#        'Air Bag-Side Head-Front', 'Air Bag-Side Head-Rear',
#        'Child Safety Rear Door Locks', 'Daytime Running Lights',
#        'Traction Control', 'Night Vision', 'Rollover Protection Bars',
#        'Basic Miles/km', 'Basic Years', 'Corrosion Miles/km',
#        'Corrosion Years', 'Drivetrain Miles/km', 'Drivetrain Years',
#        'Turning Diameter - Curb to Curb (ft)', 'Front Wheel Material',
#        'Roadside Assistance Miles/km', 'Manufacturer', 'Model year',
#        'Category', 'Front tire width', 'Front tire aspect ratio',
#        'Front tire rim size'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

to_normalize = ['EPA Fuel Economy Est - City (MPG)', 'Engine', 'Drivetrain',
       'Passenger Capacity', 'Passenger Doors', 'Wheelbase (in)',
       'SAE Net Torque @ RPM', 'Fuel System', 'SAE Net Horsepower @ RPM',
       'Displacement', 'Trans Description Cont.', 'Trans Type',
       'Air Bag-Side Head-Front', 'Air Bag-Side Head-Rear',
       'Child Safety Rear Door Locks', 'Daytime Running Lights',
       'Traction Control', 'Night Vision', 'Rollover Protection Bars',
       'Basic Miles/km', 'Basic Years', 'Corrosion Miles/km',
       'Corrosion Years', 'Drivetrain Miles/km', 'Drivetrain Years',
       'Turning Diameter - Curb to Curb (ft)', 'Front Wheel Material',
       'Roadside Assistance Miles/km', 'Manufacturer', 'Model year',
       'Category', 'Front tire width', 'Front tire aspect ratio',
       'Front tire rim size']

df_normalized = df[to_normalize]
df_normalized

mm = MinMaxScaler() # creating an instance of the class object
df_normalized = pd.DataFrame(mm.fit_transform(df_normalized), columns=df_normalized.columns)  #fit and transforming MinMaxScaler the dataframe 


df_normalized['MSRP'] = df['MSRP']
## adding price column
df_normalized
# Out:
#        EPA Fuel Economy Est - City (MPG)    Engine  Drivetrain  \
# 0                               0.333333  0.769231        0.50
# 1                               0.333333  0.769231        0.50
# 2                               0.333333  0.769231        0.50
# 3                               0.333333  0.769231        0.50
# 4                               0.318182  0.769231        0.25
# ...                                  ...       ...         ...
# 32257                           0.333333  0.769231        0.25
# 32258                           0.303030  0.846154        0.25
# 32259                           0.303030  0.846154        0.25
# 32260                           0.303030  0.846154        0.25
# 32261                           0.303030  0.846154        0.25
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                0.333333              1.0        0.608427
# 1                0.333333              1.0        0.608427
# ...

# %% [markdown]
# # Write to file

# %%
df_normalized
# Out:
#        EPA Fuel Economy Est - City (MPG)    Engine  Drivetrain  \
# 0                               0.333333  0.769231        0.50
# 1                               0.333333  0.769231        0.50
# 2                               0.333333  0.769231        0.50
# 3                               0.333333  0.769231        0.50
# 4                               0.318182  0.769231        0.25
# ...                                  ...       ...         ...
# 32257                           0.333333  0.769231        0.25
# 32258                           0.303030  0.846154        0.25
# 32259                           0.303030  0.846154        0.25
# 32260                           0.303030  0.846154        0.25
# 32261                           0.303030  0.846154        0.25
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                0.333333              1.0        0.608427
# 1                0.333333              1.0        0.608427
# ...

# %%
# Out:
#        EPA Fuel Economy Est - City (MPG)    Engine  Drivetrain  \
# 0                               0.333333  0.769231        0.50
# 1                               0.333333  0.769231        0.50
# 2                               0.333333  0.769231        0.50
# 3                               0.333333  0.769231        0.50
# 4                               0.318182  0.769231        0.25
# ...                                  ...       ...         ...
# 32257                           0.333333  0.769231        0.25
# 32258                           0.303030  0.846154        0.25
# 32259                           0.303030  0.846154        0.25
# 32260                           0.303030  0.846154        0.25
# 32261                           0.303030  0.846154        0.25
#
#        Passenger Capacity  Passenger Doors  Wheelbase (in)  \
# 0                0.333333              1.0        0.608427
# 1                0.333333              1.0        0.608427
# ...

# %%
df_normalized.to_csv('../datasets/cars/New_cars_preprocessed.csv', encoding='utf-8', index = False)
