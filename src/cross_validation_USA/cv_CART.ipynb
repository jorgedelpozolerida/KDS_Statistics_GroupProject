# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.metrics import r2_score
import os
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.linear_model import ElasticNetCV, ElasticNet

# %%
# Surpress globally the use of exponential numbers
pd.options.display.float_format = '{:.4f}'.format

# #feature_importance.round(3) or do it manually with this code

# %%
dataset_path_USA = os.path.join('../../datasets/USA_houseprices_2014/')
file_name_USA = 'preprocessed_data_USAhouseprices2014.csv'
df = pd.read_csv(dataset_path_USA + file_name_USA)

X = df.drop(['price'], axis = 1)
y = df['price']

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(random_state =  42)
# Train model
model = dtr.fit(X, y)

feat_importances = pd.DataFrame(model.feature_importances_, index = X.columns, columns=["Importance"])
feat_importances.sort_values(by='Importance', ascending=False, inplace=True)
feat_importances.plot(kind='barh', figsize=(5,5))

plt.ylabel('Features', fontsize = 15)
plt.xlabel('Rank Weight', fontsize = 15)
plt.title('CART - Feature Weights for USA Housing Dataset', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'CART - Feature Weights for USA Housing Dataset')

# %%
#elastic_net_USA.to_csv('../../data/cross_validation_USA/el_ranks.csv', sep=';',index=False)

# %%
output = cross_validate(dtr, X.values, y, cv=5, scoring = 'neg_mean_squared_error', return_estimator =True)

for idx,estimator in enumerate(output['estimator']):
    print("Features sorted by their score for Decision Tree estimator {}:".format(idx))
    feature_importances = pd.DataFrame(estimator.feature_importances_,
                                       index = X.columns,
                                        columns=['importance']).sort_values('importance', ascending=False)
    print(feature_importances)
# Out:
# Features sorted by their score for Decision Tree estimator 0:
#                            importance
# sqft_living                    0.5430
# statezip                       0.1366
# city                           0.0797
# sqft_lot                       0.0677
# view                           0.0371
# year_since_1st_renovation      0.0317
# bathrooms                      0.0299
# floors                         0.0185
# sqft_basement                  0.0179
# condition                      0.0143
# bedrooms                       0.0127
# waterfront                     0.0080
# have_basement                  0.0028
# Features sorted by their score for Decision Tree estimator 1:
#                            importance
# sqft_living                    0.5441
# statezip                       0.1178
# city                           0.0757
# sqft_lot                       0.0572
# bathrooms                      0.0442
# view                           0.0323
# year_since_1st_renovation      0.0285
# sqft_basement                  0.0273
# floors                         0.0250
# waterfront                     0.0166
# condition                      0.0151
# bedrooms                       0.0133
# have_basement                  0.0031
# Features sorted by their score for Decision Tree estimator 2:
#                            importance
# sqft_living                    0.5446
# statezip                       0.1232
# sqft_lot                       0.0814
# city                           0.0809
# year_since_1st_renovation      0.0356
# sqft_basement                  0.0254
# bathrooms                      0.0252
# view                           0.0217
# waterfront                     0.0180
# condition                      0.0164
# floors                         0.0155
# bedrooms                       0.0101
# have_basement                  0.0020
# Features sorted by their score for Decision Tree estimator 3:
#                            importance
# sqft_living                    0.5517
# statezip                       0.1199
# sqft_lot                       0.0729
# city                           0.0706
# bathrooms                      0.0372
# view                           0.0337
# year_since_1st_renovation      0.0301
# floors                         0.0211
# sqft_basement                  0.0202
# bedrooms                       0.0163
# condition                      0.0111
# waterfront                     0.0095
# have_basement                  0.0059
# Features sorted by their score for Decision Tree estimator 4:
#                            importance
# sqft_living                    0.5575
# statezip                       0.1246
# city                           0.0773
# sqft_lot                       0.0623
# view                           0.0390
# bathrooms                      0.0336
# sqft_basement                  0.0261
# year_since_1st_renovation      0.0231
# waterfront                     0.0177
# condition                      0.0156
# bedrooms                       0.0114
# floors                         0.0096
# have_basement                  0.0022
